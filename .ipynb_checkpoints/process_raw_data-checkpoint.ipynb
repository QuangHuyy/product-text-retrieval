# %%
from pandas import read_excel
my_sheet = 'Sheet1' # change it to your sheet name, you can find your sheet name at the bottom left of your excel file
file_name = './tdgd_laptop/laptop_page0.xlsx' # change it to the name of your excel file
df = read_excel(file_name, sheet_name = my_sheet)
print(df.head()) # shows headers with top 5 rows
# Out:
#            code     name     price  category     brand     cpu1    cpu2  \
# 0  220042001752   Laptop  23990000   Laptop      Acer   Ryzen 5   5600H
# 1  220042001666   Laptop  27990000   Laptop    Lenovo        i7  1165G7
# 2  220042001608   Laptop  22990000   Laptop       MSI        i7  10750H
# 3  220042001181   Laptop  11990000   Laptop      Acer        i3  1005G1
# 4  220042001754   Laptop   9990000   Laptop      Acer   Celeron   N4020
#
#      cpu3   ram                                              oCung  \
# 0  3.3GHz  8 GB  512 GB SSD NVMe PCIe (Có thể tháo ra, lắp than...
# 1  2.8GHz  8 GB                               512 GB SSD NVMe PCIe
# 2  2.6GHz  8 GB  512 GB SSD NVMe PCIe (Có thể tháo ra, lắp than...
# 3  1.2GHz  4 GB                               256 GB SSD NVMe PCIe
# 4  1.1GHz  4 GB                                 128 GB SSD M2 PCIe
#
#     cardManHinh1        cardManHinh2 manHinh1               manHinh2  \
# 0       Card rời        GTX 1650 4GB    15.6"  Full HD (1920 x 1080)
# 1  Card tích hợp       Intel Iris Xe      14"  Full HD (1920 x 1080)
# 2       Card rời  GTX 1650 Max-Q 4GB    15.6"  Full HD (1920 x 1080)
# 3  Card tích hợp           Intel UHD    15.6"  Full HD (1920 x 1080)
# 4  Card tích hợp       Intel UHD 600    11.6"        HD (1366 x 768)
#
#    congKetNoi1              congKetNoi2  \
# 0  3 x USB 3.2                     HDMI
# 1  1 x USB 3.2  1 x USB 3.2 (Always on)
# 2  3 x USB 3.2                     HDMI
# 3  2 x USB 2.0                     HDMI
# 4  2 x USB 3.2                     HDMI
#
#                                              thietKe  \
# 0                                            Vỏ nhựa
# 1                                        Vỏ kim loại
# 2                   Vỏ nhựa - nắp lưng bằng kim loại
# 3  Dài 363.4 mm - Rộng 247.5 mm - Dày 19.9 mm - N...
# 4  Dài 295 mm - Rộng 215 mm - Dày 20.99 mm - Nặng...
#
#                                            kichThuoc  \
# 0  Dài 363.4 mm - Rộng 255 mm - Dày 23.9 mm - Nặn...
# 1  Dài 320.6 mm - Rộng 208.18 mm - Dày 14.9 mm - ...
# 2  Dài 359 mm - Rộng 254 mm - Dày 21.7 mm - Nặng ...
# 3                                               2020
# 4                                               2021
#
#                                        thoiGianRaMat  rating
# 0  Dài 363.4 mm - Rộng 255 mm - Dày 23.9 mm - Nặn...     3.0
# 1  Dài 320.6 mm - Rộng 208.18 mm - Dày 14.9 mm - ...     3.8
# 2  Dài 359 mm - Rộng 254 mm - Dày 21.7 mm - Nặng ...     3.8
# 3                                               2020     3.8
# 4                                               2021     0.0

# %%
df2 = read_excel('./tdgd_laptop/laptop_page1.xlsx', sheet_name = my_sheet)

# %%
len(df.append(df2))
# Out:
# /tmp/ipykernel_987/2184029917.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   len(df.append(df2))
# 40

# %%
for i in range(1, 11):
    df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# Out:
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))
# /tmp/ipykernel_987/843433330.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(read_excel(f'./tdgd_laptop/laptop_page{i}.xlsx', sheet_name = my_sheet))

# %%
df.to_csv('./tdgd_laptop/laptop_all.csv', index=False)

# %%
t = df.duplicated(subset='code')

# %%
df[df['code'] == 220042001279]
# Out:
#             code     name     price  category      brand      cpu1 cpu2 cpu3  \
# 18  220042001279   Laptop  28490000   Laptop    MacBook   Apple M1
#
#      ram       oCung  ... cardManHinh2 manHinh1              manHinh2  \
# 18  8 GB  256 GB SSD  ...   7 nhân GPU    13.3"  Retina (2560 x 1600)
#
#                   congKetNoi1           congKetNoi2                  thietKe  \
# 18  2 x Thunderbolt 3 (USB-C)  Jack tai nghe 3.5 mm  Vỏ kim loại nguyên khối
#
#                                             kichThuoc  \
# 18  Dài 304.1 mm - Rộng 212.4 mm - Dày 4.1 mm đến ...
#
#                                         thoiGianRaMat rating  full_name
# 18  Dài 304.1 mm - Rộng 212.4 mm - Dày 4.1 mm đến ...    3.9
#
# [1 rows x 21 columns]

# %%
import numpy as np
df = df.replace(np.nan, '', regex=True)

# %%
df = df.drop_duplicates()

# %%
df['full_name'] = df['name'] + ' ' + df['brand'] + ' ' + df['cpu1'] + ' ' + df['cpu2'] + ' ' + df['cpu3'] + ' ' + df['ram'] + ' ' + df['oCung'] + ' ' + df['cardManHinh1'] + ' ' + df['cardManHinh2'] + ' ' + df['manHinh1'] + ' ' + df['manHinh2']

# %%
df[:5]
# Out:
#            code     name     price  category     brand     cpu1    cpu2  \
# 0  220042001752   Laptop  23990000   Laptop      Acer   Ryzen 5   5600H
# 1  220042001666   Laptop  27990000   Laptop    Lenovo        i7  1165G7
# 2  220042001608   Laptop  22990000   Laptop       MSI        i7  10750H
# 3  220042001181   Laptop  11990000   Laptop      Acer        i3  1005G1
# 4  220042001754   Laptop   9990000   Laptop      Acer   Celeron   N4020
#
#      cpu3   ram                                              oCung  ...  \
# 0  3.3GHz  8 GB  512 GB SSD NVMe PCIe (Có thể tháo ra, lắp than...  ...
# 1  2.8GHz  8 GB                               512 GB SSD NVMe PCIe  ...
# 2  2.6GHz  8 GB  512 GB SSD NVMe PCIe (Có thể tháo ra, lắp than...  ...
# 3  1.2GHz  4 GB                               256 GB SSD NVMe PCIe  ...
# 4  1.1GHz  4 GB                                 128 GB SSD M2 PCIe  ...
#
#          cardManHinh2 manHinh1               manHinh2  congKetNoi1  \
# 0        GTX 1650 4GB    15.6"  Full HD (1920 x 1080)  3 x USB 3.2
# 1       Intel Iris Xe      14"  Full HD (1920 x 1080)  1 x USB 3.2
# 2  GTX 1650 Max-Q 4GB    15.6"  Full HD (1920 x 1080)  3 x USB 3.2
# 3           Intel UHD    15.6"  Full HD (1920 x 1080)  2 x USB 2.0
# 4       Intel UHD 600    11.6"        HD (1366 x 768)  2 x USB 3.2
#
#                congKetNoi2                                            thietKe  \
# 0                     HDMI                                            Vỏ nhựa
# 1  1 x USB 3.2 (Always on)                                        Vỏ kim loại
# 2                     HDMI                   Vỏ nhựa - nắp lưng bằng kim loại
# 3                     HDMI  Dài 363.4 mm - Rộng 247.5 mm - Dày 19.9 mm - N...
# 4                     HDMI  Dài 295 mm - Rộng 215 mm - Dày 20.99 mm - Nặng...
#
#                                            kichThuoc  \
# 0  Dài 363.4 mm - Rộng 255 mm - Dày 23.9 mm - Nặn...
# 1  Dài 320.6 mm - Rộng 208.18 mm - Dày 14.9 mm - ...
# 2  Dài 359 mm - Rộng 254 mm - Dày 21.7 mm - Nặng ...
# 3                                               2020
# 4                                               2021
#
#                                        thoiGianRaMat rating  \
# 0  Dài 363.4 mm - Rộng 255 mm - Dày 23.9 mm - Nặn...    3.0
# 1  Dài 320.6 mm - Rộng 208.18 mm - Dày 14.9 mm - ...    3.8
# 2  Dài 359 mm - Rộng 254 mm - Dày 21.7 mm - Nặng ...    3.8
# 3                                               2020    3.8
# 4                                               2021    0.0
#
#                                            full_name
# 0   Laptop  Acer  Ryzen 5 5600H 3.3GHz 8 GB 512 G...
# 1   Laptop  Lenovo  i7 1165G7 2.8GHz 8 GB 512 GB ...
# 2   Laptop  MSI  i7 10750H 2.6GHz 8 GB 512 GB SSD...
# 3   Laptop  Acer  i3 1005G1 1.2GHz 4 GB 256 GB SS...
# 4   Laptop  Acer  Celeron N4020 1.1GHz 4 GB 128 G...
#
# [5 rows x 21 columns]
